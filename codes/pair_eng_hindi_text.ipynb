# %%
def remove_prefix(text, prefix):
    if text.startswith(prefix):
        return text[len(prefix):]
    return text

# %%
import os
# for path in os.path.dirname(os.listdir):
#     print(path)
eng_filenames=[]; hin_filenames=[]; full_eng_filenames=[]; full_hin_filenames=[]
for filename in os.listdir('English/txt/'):
    eng_filename = os.path.abspath('English/txt/'+filename)
    eng_filenames.append(eng_filename.split('/')[-1])
    full_eng_filenames.append(eng_filename)
    
for filename in os.listdir('Hindi/txt/'):
    hin_filename = os.path.abspath('Hindi/txt/'+filename)
    hin_filenames.append(hin_filename.split('/')[-1])
    full_hin_filenames.append(hin_filename)
    
# count=0
files=[]

print(len(eng_filenames))
print(len(hin_filenames))

c1=0;c2=0; pair=[]
with open('check.txt', 'w') as f:
    for e in eng_filenames:
        for h in hin_filenames:

                    
            if h.startswith("Hindi_Dubbing_Script_-_YnT_-_"):#file name starts with ...
                h_new = remove_prefix(h,"Hindi_Dubbing_Script_-_YnT_-_")
                if("_".join(e.split('_')[:11])=="_".join(h_new.split('_')[:11])):
                    c1=c1+1
                    print("H11",e,'=>',h_new)
                    pair.append((e,h))
                if("_".join(e.split('_')[:10])=="_".join(h_new.split('_')[:10])) and (e,h) not in pair:
                    c1=c1+1
                    print("H10",e,'=>',h_new)

                if("_".join(e.split('_')[:9])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H9",e,'=>',h_new)
                if("_".join(e.split('_')[:8])=="_".join(h_new.split('_')[:8])) and (e,h) not in pair:
                    c1=c1+1
                    print("H8",e,'=>',h_new)
                if("_".join(e.split('_')[:7])=="_".join(h_new.split('_')[:7])) and (e,h) not in pair:
                    c1=c1+1
                    print("H7",e,'=>',h_new)

                if("_".join(e.split('_')[:6])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H6",e,'=>',h_new)
                if("_".join(e.split('_')[:5])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H5",e,'=>',h_new)
                if("_".join(e.split('_')[:4])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H4",e,'=>',h_new)
                if("_".join(e.split('_')[:3])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H3",e,'=>',h_new)
                if("_".join(e.split('_')[:2])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H2",e,'=>',h_new)

                if("_".join(e.split('_')[:1])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H1",e,'=>',h_new)     
                    
            elif h.startswith('Hindi_Dubbing_Script_-_'):#file name starts with ...
                h_new = remove_prefix(h,'Hindi_Dubbing_Script_-_')
                if("_".join(e.split('_')[:11])=="_".join(h_new.split('_')[:11])):
                    c1=c1+1
                    print("H11",e,'=>',h_new)
                    pair.append((e,h))
                if("_".join(e.split('_')[:10])=="_".join(h_new.split('_')[:10])) and (e,h) not in pair:
                    c1=c1+1
                    print("H10",e,'=>',h_new)

                if("_".join(e.split('_')[:9])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H9",e,'=>',h_new)
                if("_".join(e.split('_')[:8])=="_".join(h_new.split('_')[:8])) and (e,h) not in pair:
                    c1=c1+1
                    print("H8",e,'=>',h_new)
                if("_".join(e.split('_')[:7])=="_".join(h_new.split('_')[:7])) and (e,h) not in pair:
                    c1=c1+1
                    print("H7",e,'=>',h_new)

                if("_".join(e.split('_')[:6])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H6",e,'=>',h_new)
                if("_".join(e.split('_')[:5])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H5",e,'=>',h_new)
                if("_".join(e.split('_')[:4])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H4",e,'=>',h_new)
                if("_".join(e.split('_')[:3])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H3",e,'=>',h_new)
                if("_".join(e.split('_')[:2])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H2",e,'=>',h_new)

                if("_".join(e.split('_')[:1])=="_".join(h_new.split('_')[:9])) and (e,h) not in pair:
                    c1=c1+1
                    print("H1",e,'=>',h_new)                    
                
#             else:#DOes not start with Hindi_Dubbing_Script
#                 print("EXACT MATCH",e,'=>',h)





#                 if e==h:
#                     c2=c2+1
#                     print("EXACT MATCH",e,'=>',h)
#                     f.write(e +  " => " + h +"\n")
#                 elif("_".join(e.split('_')[:3])=="_".join(h_new.split('_')[:3])):
#                     c2=c2+1
#                     if (len(e.split('_'))>=4 and len(h.split('_'))>=4 ):
#                         if(e.split('_')[3] == h_new.split('_')[3]):
#                             print('444', e, h_new)

print("c1=",c1)
print("c2=",c2)
# with open('check.txt', 'w') as f:
#     for e in eng_filenames:
#         for h in hin_filenames:
#             print(h)
#             if "Hindi_Dubbing_Script_-_" in h:
#                 print(h.lstrip("Hindi_Dubbing_Script_-_"))
# #             else:
#                 print("***",h)

#             if e==h:
#                 f.write(e +  " => " + h +"\n")
#             elif e==h.lstrip('Hindi_Dubbing_Scipts_-_'):
#                 f.write(e +  " => " + h +"\n")
# #             if(" ".join(e.split('_')[0:4])==" ".join(h.split('_')[0:4])):
# # #                 print(" ".join(e.split('_')[0:1]),"=>", " ".join(h.split('_')[0:1]))
#                 print(e,"=>",h)
# #             if e.split('_')[0:1]==h.split('_')[0:1]:
# #                 f.write(e +  " => " + h +"\n")
# Out:
# 562
# 306
# H11 The_Simplest_Way_to_a_Healthy_Life.txt => The_Simplest_Way_to_a_Healthy_Life.txt
# H11 Why_Was_Krishna_Such_a_Mischievous_Child.txt => Why_Was_Krishna_Such_a_Mischievous_Child.txt
# H11 Why_Are_We_Here.txt => Why_Are_We_Here.txt
# H11 Taking_Charge_of_Your_98_.txt => Taking_Charge_of_Your_98_.txt
# H11 Parenting-Raise_Yourself_Before_You_Raise_Your_Kids.txt => Parenting-Raise_Yourself_Before_You_Raise_Your_Kids.txt
# H11 Focusing_in_One_Direction.txt => Focusing_in_One_Direction.txt
# H11 What_is_the_Purpose_of_Life.txt => What_is_the_Purpose_of_Life.txt
# H11 Shambhavi_Mahamudra,_A_True_Miracle.doc.txt => Shambhavi_Mahamudra,_A_True_Miracle.doc.txt
# H11 Why_Food_And_Lunar_Eclipses_Are_A_Bad_Combo.txt => Why_Food_And_Lunar_Eclipses_Are_A_Bad_Combo.txt
# H11 A_20-second_Crash_Course_To_Become_More_Receptive.txt => A_20-second_Crash_Course_To_Become_More_Receptive.txt
# H11 How_Can_We_Experience_Krishna.txt => How_Can_We_Experience_Krishna.txt
# ...

# %%
import os
# for path in os.path.dirname(os.listdir):
#     print(path)
eng_filenames=[]; hin_filenames=[]; full_eng_filenames=[]; full_hin_filenames=[]
for filename in os.listdir('English/txt/'):
    eng_filename = os.path.abspath('English/txt/'+filename)
    eng_filenames.append(eng_filename.split('/')[-1])
    full_eng_filenames.append(eng_filename)
    
for filename in os.listdir('Hindi/txt/'):
    hin_filename = os.path.abspath('Hindi/txt/'+filename)
    hin_filenames.append(hin_filename.split('/')[-1])
    full_hin_filenames.append(hin_filename)
    
# count=0
files=[]

print(len(eng_filenames))
print(len(hin_filenames))

c1=0;c2=0; pair = []
with open('check.txt', 'w') as f:
    for e,e1 in zip(eng_filenames, full_eng_filenames):
        for h,h1 in zip(hin_filenames, full_hin_filenames):
            if h.startswith('Hindi_Dubbing_Script_-_'):#file name starts with ...
                h_new = remove_prefix(h,'Hindi_Dubbing_Script_-_')
                
#                 if ("_".join(e.split('_')[:2])=="_".join(h_new.split('_')[:2])):
                    
#                     print('222',e,h_new)
                    
                if("_".join(e.split('_')[:3])=="_".join(h_new.split('_')[:3])):
                    if (len(e.split('_'))>=4 and len(h.split('_'))>=4 ):
                        if(e.split('_')[3] == h_new.split('_')[3]):
                            print('444H', e, h_new)
                            pair.append((e1,h1))
                            c1=c1+1
#                         elif()
                    
                    else: #length is < 4
                        print('333H---',e,'=>',h_new)
                        pair.append((e1,h1))
                        c1=c1+1

            else:#Exact same case
                
                if e==h:
                    c2=c2+1
                    print("EXACT MATCH",e,'=>',h)
                    pair.append((e1,h1))
                    f.write(e +  " => " + h +"\n")
                elif("_".join(e.split('_')[:3])=="_".join(h_new.split('_')[:3])):
                    c2=c2+1
                    if (len(e.split('_'))>=4 and len(h.split('_'))>=4 ):
                        if(e.split('_')[3] == h_new.split('_')[3]):
                            print('444', e, h_new)
                            pair.append((e1,h1))

print("c1=",c1)
print("c2=",c2)
print(pair)
# with open('check.txt', 'w') as f:
#     for e in eng_filenames:
#         for h in hin_filenames:
#             print(h)
#             if "Hindi_Dubbing_Script_-_" in h:
#                 print(h.lstrip("Hindi_Dubbing_Script_-_"))
# #             else:
#                 print("***",h)

#             if e==h:
#                 f.write(e +  " => " + h +"\n")
#             elif e==h.lstrip('Hindi_Dubbing_Scipts_-_'):
#                 f.write(e +  " => " + h +"\n")
# #             if(" ".join(e.split('_')[0:4])==" ".join(h.split('_')[0:4])):
# # #                 print(" ".join(e.split('_')[0:1]),"=>", " ".join(h.split('_')[0:1]))
#                 print(e,"=>",h)
# #             if e.split('_')[0:1]==h.split('_')[0:1]:
# #                 f.write(e +  " => " + h +"\n")
# Out:
# 562
# 306
# 444H The_Simplest_Way_to_a_Healthy_Life.txt The_Simplest_Way_to_a_Healthy_Life.txt
# 444H Why_Do_People_Get_Thyroid_Problems.doc.txt Why_Do_People_Get_Thyroid_Problems.txt
# 444 Why_Do_People_Get_Thyroid_Problems.doc.txt Why_Do_People_Get_Thyroid_Problems.txt
# 444H How_Do_I_Deal_With_Unfulfilled_Expectations.doc.txt How_Do_I_Deal_With_Unfulfilled_Expectations.txt
# 444H How_Can_the_Mind_Be_Quiet.doc.txt How_Can_the_Mind_Be_Quiet.txt
# 444H Why_Was_Krishna_Such_a_Mischievous_Child.txt Why_Was_Krishna_Such_a_Mischievous_Child.txt
# 444H Why_Are_We_Here.txt Why_Are_We_Here.txt
# 444H How_to_Find_Your_Guru.doc.txt How_to_Find_Your_Guru.txt
# 444H Taking_Charge_of_Your_98_.txt Taking_Charge_of_Your_98_.txt
# 444H Parenting-Raise_Yourself_Before_You_Raise_Your_Kids.txt Parenting-Raise_Yourself_Before_You_Raise_Your_Kids.txt
# 444H Focusing_in_One_Direction.txt Focusing_in_One_Direction.txt
# ...

# %%
#Copying files from respective directories:
import os 
parent_dir = "/home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/align_doc"
from shutil import copyfile
count =0
for i in pair:
    directory = i[0].split('/')[-1]
    path = os.path.join(parent_dir, directory) 
    try:
        os.mkdir(path) 
        copyfile(i[0], path+'/'+i[0].split('/')[-1])
        h_parent_dir = parent_dir + '/' + directory
        h_path = os.path.join(h_parent_dir + '/H')
        try:
            os.mkdir(h_path)
            copyfile(i[1], h_path+'/'+i[1].split('/')[-1])

        except OSError as error:
            print("H folder:", error)

    except OSError as error: 
        print("**",error) 
    print(i[0])
    count=count+1
count
    
#     break
# Out:
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/The_Simplest_Way_to_a_Healthy_Life.txt
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/Why_Do_People_Get_Thyroid_Problems.doc.txt
# ** [Errno 17] File exists: '/home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/align_doc/Why_Do_People_Get_Thyroid_Problems.doc.txt'
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/Why_Do_People_Get_Thyroid_Problems.doc.txt
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/How_Do_I_Deal_With_Unfulfilled_Expectations.doc.txt
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/How_Can_the_Mind_Be_Quiet.doc.txt
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/Why_Was_Krishna_Such_a_Mischievous_Child.txt
# /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/English/txt/Why_Are_We_Here.txt
# ...

# %%
# !ls /home/kishori/ILP_isha/08012021_all_video_data/extracted_zip/
# Out:
# align_doc			       extract_eng_hindi_alignment.txt
# all_english_files.txt		       Hindi
# check_extract_eng_hindi_alignment.txt  hindi_txt_bkup
# check.txt			       pair_eng_hindi_text.ipynb
# cp_of_duplicate_files_in_Hindi_txt     rename_hin_files.sh
# doc2txt.sh			       space2undescore.sh
# duplicate_files_in_Hindi_txt	       YouTube_Hindi_Update.xlsx
# English
